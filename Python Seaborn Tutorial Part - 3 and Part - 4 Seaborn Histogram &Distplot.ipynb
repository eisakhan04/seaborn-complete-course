# %% [markdown]
# ## Python Seaborn Tutorial Part - 3 and Part - 4 ,Seaborn Histogram / Seaborn Distplot

# %% [markdown]
# # what is Seaborn Histogram / Seaborn Distplot

# %% [markdown]
# Seaborn offers two main functions for visualizing the distribution of data: sns.histplot() and sns.distplot(). These functions are used to create histograms and distribution plots, respectively. Here's an explanation of each:
#
# **Seaborn Histogram (sns.histplot()):**
#
# A histogram is a graphical representation of the distribution of a dataset. It divides the data into bins or intervals and displays the frequency or count of data points within each bin.
# Seaborn's **sns.histplot() function** is designed specifically for creating histograms. It allows you to visualize the distribution of a single variable.
# You can customize the number of bins, color, transparency, and other aesthetic properties of the histogram to tailor it to your needs.
# Histograms are useful for understanding the shape, central tendency, and spread of a dataset. They can reveal patterns such as whether the data is normally distributed, skewed, or has multiple modes.
# Seaborn Distribution Plot **(sns.distplot()):**
#
# A distribution plot is a more versatile plot that combines a histogram with other elements, such as a kernel density estimate (KDE) or a fitted probability distribution. This provides a more detailed view of the data's distribution.
# Seaborn's **sns.distplot()** function can create distribution plots. It allows you to visualize the distribution of a single variable and overlay a KDE curve or fit a parametric distribution (like a normal distribution) to the data.
# Distribution plots are helpful for gaining insights into the data's distribution characteristics and for comparing it to theoretical distributions.
# The sns.distplot() function has been deprecated in newer Seaborn versions in favor of sns.histplot() and sns.kdeplot(), which provide more control and flexibility over the components of the distribution plot.
# In summary, Seaborn provides functions like **sns.histplot()** and **sns.distplot()** to create histograms and distribution plots, respectively, allowing you to explore and visualize the distribution of your data in different ways. These plots are valuable tools for understanding the underlying patterns and characteristics of your datasets.

# %% [markdown]
# ## How to draw Seaborn Histogram / Seaborn Distplot

# %%
import seaborn as sns # for data visulization 
import matplotlib.pyplot as plt # for data visulization 
import scipy.stats as norm # for data scientific computing

# %%
#Load "tips" DataFrame from GitHub seaborn repository
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(df["total_bill"])
#sns.set()
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\4085317194.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(df["size"])
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\849509978.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["size"])
# <Axes: xlabel='size', ylabel='Density'>

# %%
sns.distplot(df["tip"])
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\2034962720.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["tip"])
# <Axes: xlabel='tip', ylabel='Density'>

# %% [raw]
# Signature:
# sns.distplot(
#     a=None,
#     bins=None,
#     hist=True,
#     kde=True,
#     rug=False,
#     fit=None,
#     hist_kws=None,
#     kde_kws=None,
#     rug_kws=None,
#     fit_kws=None,
#     color=None,
#     vertical=False,
#     norm_hist=False,
#     axlabel=None,
#     label=None,
#     ax=None,
#     x=None,
# )
# Docstring:
# DEPRECATED
#
# This function has been deprecated and will be removed in seaborn v0.14.0.
# It has been replaced by :func:`histplot` and :func:`displot`, two functions
# with a modern API and many more capabilities.
#
# For a guide to updating, please see this notebook:
#
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# File:      c:\anaconda\lib\site-packages\seaborn\distributions.py
# Type:      function

# %%
sns.distplot(df["total_bill"] , bins=100)
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\2768038499.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"] , bins=100)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(df["total_bill"] , bins=100 , hist=False, )
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\1500563122.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"] , bins=100 , hist=False, )
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(df["total_bill"] , bins=100 , hist=True, kde = False  )
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\794593099.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"] , bins=100 , hist=True, kde = False  )
# <Axes: xlabel='total_bill'>

# %%
sns.distplot(df["total_bill"] , hist=True, kde = True   ,rug=True)
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\1482563039.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"] , hist=True, kde = True   ,rug=True)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(df["total_bill"] , hist=True, kde = False   ,rug=True )
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\3410980396.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"] , hist=True, kde = False   ,rug=True )
# <Axes: xlabel='total_bill'>

# %%
sns.distplot(df["total_bill"] , hist=True, kde = True   ,rug=True , color='r')
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\1766822580.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"] , hist=True, kde = True   ,rug=True , color='r')
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(df["total_bill"] , hist=True, kde = True   ,rug=True , color='r', vertical=True )
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\3230579519.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"] , hist=True, kde = True   ,rug=True , color='r', vertical=True )
# <Axes: xlabel='Density', ylabel='total_bill'>

# %%
sns.distplot(df["total_bill"] , hist=True, kde = True   ,rug=True , color='r', vertical=False ,)
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\3180387356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"] , hist=True, kde = True   ,rug=True , color='r', vertical=False ,)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(df["total_bill"], norm_hist=False)
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\1472099828.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"], norm_hist=False)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
 sns.distplot(df["total_bill"], norm_hist=False, axlabel="Total Bill")
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\3420080151.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"], norm_hist=False, axlabel="Total Bill")
# <Axes: xlabel='Total Bill', ylabel='Density'>

# %%
sns.distplot(df["total_bill"],  axlabel="Total Bill" , label = "Total Bill")
plt.title("Histogram of total Bill")
plt.legend()
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\3577922185.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"],  axlabel="Total Bill" , label = "Total Bill")

# %%
df.total_bill.sort_values() # to know norder of values
# Out:
# 67      3.07
# 92      5.75
# 111     7.25
# 172     7.25
# 149     7.51
#        ...
# 182    45.35
# 156    48.17
# 59     48.27
# 212    48.33
# 170    50.81
# Name: total_bill, Length: 244, dtype: float64

# %%
# Modify histogram with bins  
bins = [1,5,10,15,20,25,30,35,40,45,50,55] # list

plt.figure(figsize=(16,9))
sns.set()

sns.distplot(df["total_bill"], bins = bins)

plt.xticks(bins) # set bins value

plt.title("Histogram of Total Bill") 
plt.show()
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\886116853.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"], bins = bins)

# %% [markdown]
# The provided code modifies a histogram using Seaborn to visualize the distribution of a dataset, specifically the "total_bill" column from the DataFrame df. Here are the key aspects of the code:
#
# **Bins Configuration:** It defines a custom list of bin edges named bins. These bin edges determine the intervals into which the data will be grouped for the histogram. Each bin represents a range of values.
#
# **Plot Size and Style:** It sets the figure size to (16, 9) using plt.figure(figsize=(16, 9)) to adjust the dimensions of the plot. Additionally, sns.set() is called to apply the default Seaborn style to the plot.
#
# **Seaborn distplot():** It uses Seaborn's sns.distplot() function to create the histogram. The df["total_bill"] column is passed as the data to be visualized, and the specified bins list is used to determine the bin edges.
#
# **X-axis Ticks:** plt.xticks(bins) is used to set custom tick positions on the x-axis. This ensures that the tick marks correspond to the bin edges defined in the bins list.
#
# **Plot Title:** It sets the title of the histogram to "Histogram of Total Bill" using plt.title().
#
# **Display Plot:** Finally, plt.show() is called to display the modified histogram.
#
# In summary, this code customizes a histogram's bin edges using the provided bins list, adjusts the plot size and style, and sets custom x-axis tick positions for better control and visualization of the "total_bill" distribution.

# %%
plt.figure(figsize = (16,9))
sns.set()
# hist keyword argument to change hist format
sns.distplot(df["total_bill"] , 
             
             hist_kws = {  'color' : '#DC143C'  ,'edgecolor': '#aaff00' , 'linewidth':10 , 'linestyle': '--' ,'alpha':0.9}  )
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\3665144677.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"] ,
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
plt.figure(figsize=(16,9))
sns.set()

# hist keyword argument to change hist format
sns.distplot(df["total_bill"],
            hist_kws = {'color':'#DC143C', 'edgecolor':'#aaff00',
                       'linewidth':5, 'linestyle':'--', 'alpha':0.9}) # hist keyword parameter to change hist format
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\1698779950.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"],
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
plt.figure(figsize=(16,9))
sns.set()

# hist keyword argument to change hist format
sns.distplot(df["total_bill"],
            hist_kws = {'color':'#DC143C', 'edgecolor':'#aaff00',
                       'linewidth':5, 'linestyle':'--', 'alpha':0.9}, # hist keyword parameter to change hist format
              kde_kws = {'color':'#8e00ce', 
                       'linewidth':8, 'linestyle':'--', 'alpha':0.9},
              rug= True,
              rug_kws = {'color':'#0426d0', 'edgecolor':'#00dbff',
                       'linewidth':5, 'linestyle':'--', 'alpha':0.8})
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\625041971.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"],
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
plt.figure(figsize=(16,9))
#sns.set()
# hist keyword argument to change hist format
sns.distplot(df["total_bill"],
            hist_kws = {'color':'#DC143C', 'edgecolor':'#aaff00',
                       'linewidth':5, 'linestyle':'--', 'alpha':0.9}, # hist keyword parameter to change hist format
              kde_kws = {'color':'#8e00ce', 
                       'linewidth':8, 'linestyle':'--', 'alpha':0.9},
                rug = True,
            rug_kws = {'color':'#0426d0', 'edgecolor':'#00dbff',
                       'linewidth':5, 'linestyle':'--', 'alpha':0.8})
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\2600106572.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"],
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
plt.figure(figsize=(16,9))
sns.set()

# hist keyword argument to change hist format
sns.distplot(df["total_bill"],
            hist_kws = {'color':'#DC143C', 'edgecolor':'#aaff00','linewidth':5, 'linestyle':'--', 'alpha':0.9},# hist keyword parameter to change hist format
             kde=False,
             fit=norm,
           #  fit_kws = {'color':'#8e00ce', 'linewidth':12, 'linestyle':'--', 'alpha':0.4},
             rug = True,
            rug_kws = {'color':'#0426d0', 'edgecolor':'#00dbff','linewidth':5, 'linestyle':'--', 'alpha':0.9})
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\4072105522.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"],
# <Axes: xlabel='total_bill'>

# %%
plt.figure(figsize=(16,9))
sns.set()

# hist, fit and rug keyword  argument to change hist format
sns.distplot(df["total_bill"],
            hist_kws = {'color':'#DC143C', 'edgecolor':'#aaff00',
                       'linewidth':5, 'linestyle':'--', 'alpha':0.9},
            
            kde=False,
            fit = norm,
            fit_kws = {'color':'#8e00ce', 
                       'linewidth':12, 'linestyle':'--', 'alpha':0.4},
            rug = True,
            rug_kws = {'color':'#0426d0', 'edgecolor':'#00dbff',
                       'linewidth':5, 'linestyle':'--', 'alpha':0.9},)
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\1730843386.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"],
# <Axes: xlabel='total_bill'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

plt.figure(figsize=(16, 9))
sns.set()

bins = [1, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]

# Load your data into the "df" DataFrame before using it in this code

sns.distplot(df["total_bill"], bins=bins,
             hist_kws={'color': '#DC143C', 'edgecolor': '#aaff00',
                       'linewidth': 5, 'linestyle': '--', 'alpha': 0.9},
             kde=False,
             fit=norm,
             fit_kws={'color': '#8e00ce',
                      'linewidth': 2, 'linestyle': '--', 'alpha': 0.4},  # Fixed typo in linewidth
             rug=True,
             rug_kws={'color': '#0426d0', 'edgecolor': '#00dbff',
                      'linewidth': 3, 'linestyle': '--', 'alpha': 0.9},
             label="TB")

plt.xticks(bins)
plt.title("Histogram of Restaurant Total Bill", fontsize=20)  # Fixed typo in "Restorant"
plt.xlabel("Total Bill", fontsize=15)
plt.legend()
plt.show()
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\3902922664.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"], bins=bins,

# %%
# Plot multiple seaborn histogram in single graph
plt.figure(figsize=(16,9))
sns.distplot(df["total_bill"], bins=9, label="total_bil")
sns.distplot(df["tip"], bins=9, label="tip")
sns.distplot(df["size"], bins=9, label = "size")

plt.legend()
# Out:
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\173958548.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total_bill"], bins=9, label="total_bil")
# C:\Users\LAPTOPS  HUB\AppData\Local\Temp\ipykernel_5428\173958548.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# ...
